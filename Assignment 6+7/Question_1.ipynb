# %%
import requests
from bs4 import BeautifulSoup

def extract(page):
    user_agent = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}
    url = f'https://www.rozee.pk/job/jsearch/q/AI/ML%20Engineer'
    r = requests.get(url, headers=user_agent)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

def transform(soup):
    job_titles = soup.select('/html/body/div[3]/div/div[2]/div[2]/div[3]/div[1]/div[1]/div/h3')
    for title in job_titles:
        print(title.text.strip())
    return len(job_titles)

page_content = extract(0)
print(transform(page_content))
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# d:\Semester 2\Programming For AI(python)\Assignment 6+7\Question_1.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Assignment%206%2B7/Question_1.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a>     return len(job_titles)
#      <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Assignment%206%2B7/Question_1.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a> page_content = extract(0)
# ---> <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Assignment%206%2B7/Question_1.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a> print(transform(page_content))
#
# d:\Semester 2\Programming For AI(python)\Assignment 6+7\Question_1.ipynb Cell 1 line 1
# ...

# %%
import requests 
from bs4 import BeautifulSoup
def extract(page):
    us_agent = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"}
    url = f'https://pk.indeed.com/'
    r = requests.get(url, us_agent)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup
def transform(soup):
    divs = soup.find_all('div', class_='job')
    print(divs)
    for item in divs:
        
        print(title)
    return len(divs)

c = extract(0)
print(transform(c))
# Out:
# [<div class="job">
# <div class="jcont">
# <div class="jhead">
# <div class="panel-effect ht40 wt80">
# <div class="dvdr"></div>
# <div class="dvdr vt"></div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="jbody">
# <div class="panel-effect ht20">
# </div>
# <div class="panel-effect mt10 ht20 wt80">
# </div>
# </div>
# </div>
# <div class="jfooter">
# <div class="row">
# <div class="col-md-12 float-left">
# <div class="panel-effect wt70 ht20">
# <div class="dvdr"></div>
# <div class="dvdr two"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>, <div class="job">
# <div class="jcont">
# <div class="jhead">
# <div class="panel-effect ht40 wt80">
# <div class="dvdr"></div>
# <div class="dvdr vt"></div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="jbody">
# <div class="panel-effect ht20">
# </div>
# <div class="panel-effect mt10 ht20 wt80">
# </div>
# </div>
# </div>
# <div class="jfooter">
# <div class="row">
# ...
